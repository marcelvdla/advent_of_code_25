# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
with open("leaderboard.json", "r") as f:
    leaderboard_data = json.load(f)

leaderboard_data
# Out:
# {'members': {'5129410': {'local_score': 0,
#    'stars': 0,
#    'last_star_ts': 0,
#    'id': 5129410,
#    'name': 'Lina Al Najar',
#    'completion_day_level': {}},
#   '2281623': {'completion_day_level': {'5': {'2': {'star_index': 98,
#       'get_star_ts': 1764918759},
#      '1': {'get_star_ts': 1764918143, 'star_index': 97}},
#     '3': {'1': {'get_star_ts': 1764745809, 'star_index': 45},
#      '2': {'star_index': 73, 'get_star_ts': 1764779422}},
#     '4': {'1': {'get_star_ts': 1764832717, 'star_index': 79},
#      '2': {'get_star_ts': 1764833110, 'star_index': 81}},
#     '7': {'2': {'star_index': 134, 'get_star_ts': 1765098433},
#      '1': {'star_index': 133, 'get_star_ts': 1765097478}},
#     '2': {'2': {'star_index': 42, 'get_star_ts': 1764690619},
#      '1': {'get_star_ts': 1764660163, 'star_index': 21}},
#     '1': {'2': {'get_star_ts': 1764604798, 'star_index': 19},
#      '1': {'star_index': 0, 'get_star_ts': 1764573524}},
# ...
